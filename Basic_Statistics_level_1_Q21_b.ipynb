# %% [markdown]
# <a href="https://colab.research.google.com/github/Prithviraj2706/DataScience-Assignment/blob/main/Basic_Statistics_level_1_Q21_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/wc-at.csv')

# %%
data.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
# plotting distribution for Waist Circumference (Waist)
sns.distplot(data['Waist'])
# Out:
# <ipython-input-97-e871187241f4>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Waist'])
# <Axes: xlabel='Waist', ylabel='Density'>

# %%
# plotting distribution for Adipose Tissue (AT)
sns.distplot(data.AT)
plt.ylabel('Density')
plt.show()
# Out:
# <ipython-input-101-e99a83955ecd>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.AT)

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
#Waist
data['Waist'].mean()  , data['Waist'].median()
# Out:
# (91.90183486238531, 90.8)

# %%
#AT
data['AT'].mean()  ,   data['AT'].median()
# Out:
# (101.89403669724771, 96.54)

# %%
sns.regplot(data,x='Waist', y='AT')
# Out:
# <Axes: xlabel='Waist', ylabel='AT'>
