# %% [markdown]
# <a href="https://colab.research.google.com/github/Prithviraj2706/DataScience-Assignment/blob/main/Multilinear_problem(50_startup_problem).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv('/content/50_Startups (1).csv')

# %%
data
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
data.isna()
# Out:
#     R&D Spend  Administration  Marketing Spend  State  Profit
# 0       False           False            False  False   False
# 1       False           False            False  False   False
# 2       False           False            False  False   False
# 3       False           False            False  False   False
# 4       False           False            False  False   False
# 5       False           False            False  False   False
# 6       False           False            False  False   False
# 7       False           False            False  False   False
# 8       False           False            False  False   False
# 9       False           False            False  False   False
# 10      False           False            False  False   False
# 11      False           False            False  False   False
# 12      False           False            False  False   False
# 13      False           False            False  False   False
# ...

# %%
data.corr()
# Out:
# <ipython-input-19-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
import seaborn as sn
sn.heatmap(data.corr(),annot=True)
# Out:
# <ipython-input-20-ba2134b77aa8>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sn.heatmap(data.corr(),annot=True)
# <Axes: >

# %%
#splitting the dependent and Independent variabeles
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %%
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'Florida'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'Florida'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'Florida'],
#        [100671.96, 91790.61, 249744.55, 'California'],
#        [93863.75, 127320.38, 249839.44, 'Florida'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
# ...

# %%
#encoding the independent variable
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[3])],remainder='passthrough')
X=np.array(ct.fit_transform(X))

# %%
X
# Out:
# array([[0.0, 0.0, 1.0, 165349.2, 136897.8, 471784.1],
#        [1.0, 0.0, 0.0, 162597.7, 151377.59, 443898.53],
#        [0.0, 1.0, 0.0, 153441.51, 101145.55, 407934.54],
#        [0.0, 0.0, 1.0, 144372.41, 118671.85, 383199.62],
#        [0.0, 1.0, 0.0, 142107.34, 91391.77, 366168.42],
#        [0.0, 0.0, 1.0, 131876.9, 99814.71, 362861.36],
#        [1.0, 0.0, 0.0, 134615.46, 147198.87, 127716.82],
#        [0.0, 1.0, 0.0, 130298.13, 145530.06, 323876.68],
#        [0.0, 0.0, 1.0, 120542.52, 148718.95, 311613.29],
#        [1.0, 0.0, 0.0, 123334.88, 108679.17, 304981.62],
#        [0.0, 1.0, 0.0, 101913.08, 110594.11, 229160.95],
#        [1.0, 0.0, 0.0, 100671.96, 91790.61, 249744.55],
#        [0.0, 1.0, 0.0, 93863.75, 127320.38, 249839.44],
#        [1.0, 0.0, 0.0, 91992.39, 135495.07, 252664.93],
#        [0.0, 1.0, 0.0, 119943.24, 156547.42, 256512.92],
#        [0.0, 0.0, 1.0, 114523.61, 122616.84, 261776.23],
#        [1.0, 0.0, 0.0, 78013.11, 121597.55, 264346.06],
# ...

# %%
#avaoiding the dummy trap
X=X[:,1:]

# %%
X
# Out:
# array([[0.0, 1.0, 165349.2, 136897.8, 471784.1],
#        [0.0, 0.0, 162597.7, 151377.59, 443898.53],
#        [1.0, 0.0, 153441.51, 101145.55, 407934.54],
#        [0.0, 1.0, 144372.41, 118671.85, 383199.62],
#        [1.0, 0.0, 142107.34, 91391.77, 366168.42],
#        [0.0, 1.0, 131876.9, 99814.71, 362861.36],
#        [0.0, 0.0, 134615.46, 147198.87, 127716.82],
#        [1.0, 0.0, 130298.13, 145530.06, 323876.68],
#        [0.0, 1.0, 120542.52, 148718.95, 311613.29],
#        [0.0, 0.0, 123334.88, 108679.17, 304981.62],
#        [1.0, 0.0, 101913.08, 110594.11, 229160.95],
#        [0.0, 0.0, 100671.96, 91790.61, 249744.55],
#        [1.0, 0.0, 93863.75, 127320.38, 249839.44],
#        [0.0, 0.0, 91992.39, 135495.07, 252664.93],
#        [1.0, 0.0, 119943.24, 156547.42, 256512.92],
#        [0.0, 1.0, 114523.61, 122616.84, 261776.23],
#        [0.0, 0.0, 78013.11, 121597.55, 264346.06],
#        [0.0, 1.0, 94657.16, 145077.58, 282574.31],
# ...

# %%
#splitiing the test and train columns
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=.2,random_state=0)

# %%
X_train
# Out:
# array([[1.0, 0.0, 28663.76, 127056.21, 201126.82],
#        [0.0, 1.0, 78389.47, 153773.43, 299737.29],
#        [0.0, 1.0, 86419.7, 153514.11, 0.0],
#        [0.0, 0.0, 123334.88, 108679.17, 304981.62],
#        [0.0, 0.0, 38558.51, 82982.09, 174999.3],
#        [1.0, 0.0, 1315.46, 115816.21, 297114.46],
#        [0.0, 1.0, 144372.41, 118671.85, 383199.62],
#        [0.0, 1.0, 165349.2, 136897.8, 471784.1],
#        [0.0, 0.0, 0.0, 135426.92, 0.0],
#        [0.0, 0.0, 22177.74, 154806.14, 28334.72]], dtype=object)

# %%
X_test
# Out:
# array([[1.0, 0.0, 66051.52, 182645.56, 118148.2],
#        [0.0, 0.0, 100671.96, 91790.61, 249744.55],
#        [1.0, 0.0, 101913.08, 110594.11, 229160.95],
#        [1.0, 0.0, 27892.92, 84710.77, 164470.71],
#        [1.0, 0.0, 153441.51, 101145.55, 407934.54],
#        [0.0, 1.0, 72107.6, 127864.55, 353183.81],
#        [0.0, 1.0, 20229.59, 65947.93, 185265.1],
#        [0.0, 1.0, 61136.38, 152701.92, 88218.23],
#        [1.0, 0.0, 73994.56, 122782.75, 303319.26],
#        [1.0, 0.0, 142107.34, 91391.77, 366168.42],
#        [1.0, 0.0, 55493.95, 103057.49, 214634.81],
#        [0.0, 1.0, 46014.02, 85047.44, 205517.64],
#        [1.0, 0.0, 75328.87, 144135.98, 134050.07],
#        [0.0, 0.0, 46426.07, 157693.92, 210797.67],
#        [1.0, 0.0, 91749.16, 114175.79, 294919.57],
#        [1.0, 0.0, 130298.13, 145530.06, 323876.68],
#        [1.0, 0.0, 119943.24, 156547.42, 256512.92],
#        [0.0, 1.0, 1000.23, 124153.04, 1903.93],
#        [0.0, 1.0, 542.05, 51743.15, 0.0],
# ...

# %%
y_train
# Out:
# array([ 90708.19, 111313.02, 122776.86, 149759.96,  81005.76,  49490.75,
#        182901.99, 192261.83,  42559.73,  65200.33])

# %%
y_test
# Out:
# array([103282.38, 144259.4 , 146121.95,  77798.83, 191050.39, 105008.31,
#         81229.06,  97483.56, 110352.25, 166187.94,  96778.92,  96479.51,
#        105733.54,  96712.8 , 124266.9 , 155752.6 , 132602.65,  64926.08,
#         35673.41, 101004.64, 129917.04,  99937.59,  97427.84, 126992.93,
#         71498.49, 118474.03,  69758.98, 152211.77, 134307.35, 107404.34,
#        156991.12, 125370.37,  78239.91,  14681.4 , 191792.06, 141585.52,
#         89949.14, 108552.04, 156122.51, 108733.99])

# %%
#fitiing the data
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)
y_pred
# Out:
# array([117126.70277514, 136353.43123955, 154866.10395969,  87795.01634386,
#        200500.87793945, 107171.97607321,  67068.16608256, 101294.12858994,
#        125158.01627685, 191544.16615367, 111390.19919478,  89622.25061194,
#        128928.24109191,  79677.28671274, 143132.94690159, 176645.18169729,
#        167493.75212882,  48314.47478707,  54157.61058745, 105065.75252076,
#        150620.66545457, 119697.02235497, 102620.78149321, 111693.71044143,
#         64736.96257497, 109795.04699665,  61080.92520259, 152868.46567273,
#        124196.27007284, 100585.03690586, 166632.62073429, 129111.60170869,
#         67079.74210358,  42915.26813872, 185618.28003357, 145181.37554742,
#         86931.63646706, 119802.54178756, 167241.99305039, 120392.82714268])

# %%
y_test
# Out:
# array([103282.38, 144259.4 , 146121.95,  77798.83, 191050.39, 105008.31,
#         81229.06,  97483.56, 110352.25, 166187.94,  96778.92,  96479.51,
#        105733.54,  96712.8 , 124266.9 , 155752.6 , 132602.65,  64926.08,
#         35673.41, 101004.64, 129917.04,  99937.59,  97427.84, 126992.93,
#         71498.49, 118474.03,  69758.98, 152211.77, 134307.35, 107404.34,
#        156991.12, 125370.37,  78239.91,  14681.4 , 191792.06, 141585.52,
#         89949.14, 108552.04, 156122.51, 108733.99])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, mean_absolute_percentage_error, r2_score
mape = mean_absolute_percentage_error(y_true=y_test,y_pred=y_pred)
rsquare = r2_score(y_true=y_test, y_pred=y_pred)
print('mape=', mape)
print('rsquare= ', rsquare)
# Out:
# mape= 0.16061657178897487
# rsquare=  0.8481562802724495

# %%
#BUILDING THE OPTIMAL MODEL
import statsmodels.api as sm
X= np.append(arr=np.ones((50,1)).astype(int),values=X,axis=1)

# %%
X
# Out:
# array([[1, 0.0, 1.0, 165349.2, 136897.8, 471784.1],
#        [1, 0.0, 0.0, 162597.7, 151377.59, 443898.53],
#        [1, 1.0, 0.0, 153441.51, 101145.55, 407934.54],
#        [1, 0.0, 1.0, 144372.41, 118671.85, 383199.62],
#        [1, 1.0, 0.0, 142107.34, 91391.77, 366168.42],
#        [1, 0.0, 1.0, 131876.9, 99814.71, 362861.36],
#        [1, 0.0, 0.0, 134615.46, 147198.87, 127716.82],
#        [1, 1.0, 0.0, 130298.13, 145530.06, 323876.68],
#        [1, 0.0, 1.0, 120542.52, 148718.95, 311613.29],
#        [1, 0.0, 0.0, 123334.88, 108679.17, 304981.62],
#        [1, 1.0, 0.0, 101913.08, 110594.11, 229160.95],
#        [1, 0.0, 0.0, 100671.96, 91790.61, 249744.55],
#        [1, 1.0, 0.0, 93863.75, 127320.38, 249839.44],
#        [1, 0.0, 0.0, 91992.39, 135495.07, 252664.93],
#        [1, 1.0, 0.0, 119943.24, 156547.42, 256512.92],
#        [1, 0.0, 1.0, 114523.61, 122616.84, 261776.23],
#        [1, 0.0, 0.0, 78013.11, 121597.55, 264346.06],
# ...

# %%
#Backward Elimination
X_opt=X[:,[0,1,2,3,4,5]]
X_opt=np.array(X_opt,dtype=float)
regressor_OLS=sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Mon, 22 May 2023   Prob (F-statistic):           1.34e-27
# Time:                        11:16:40   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.013e+04   6884.820      7.281      0.000    3.62e+04     6.4e+04
# ...

# %%
#Backward Elimination
X_opt=X[:,[0,1,3,4,5]]
X_opt=np.array(X_opt,dtype=float)
regressor_OLS=sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Mon, 22 May 2023   Prob (F-statistic):           8.49e-29
# Time:                        11:16:40   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.011e+04   6647.870      7.537      0.000    3.67e+04    6.35e+04
# ...

# %%
#Backward Elimination
X_opt=X[:,[0,3,4,5]]
X_opt=np.array(X_opt,dtype=float)
regressor_OLS=sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Mon, 22 May 2023   Prob (F-statistic):           4.53e-30
# Time:                        11:16:40   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# ...

# %%
#Backward Elimination
X_opt=X[:,[0,3,5]]
X_opt=np.array(X_opt,dtype=float)
regressor_OLS=sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Mon, 22 May 2023   Prob (F-statistic):           2.16e-31
# Time:                        11:16:40   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.698e+04   2689.933     17.464      0.000    4.16e+04    5.24e+04
# ...

# %%
#Backward Elimination
X_opt=X[:,[0,3]]
X_opt=np.array(X_opt,dtype=float)
regressor_OLS=sm.OLS(endog=y,exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Mon, 22 May 2023   Prob (F-statistic):           3.50e-32
# Time:                        11:16:40   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.903e+04   2537.897     19.320      0.000    4.39e+04    5.41e+04
# ...

# %%
#DATA VISUALIZATION
import seaborn as sns 
sns.lmplot(x="R&D Spend",y="Profit",data=data)

# %%
#DATA VISUALIZATION
import seaborn as sns 
sns.lmplot(x="Administration",y="Profit",data=data)

# %%
# Lasso Regression
from sklearn.linear_model import Lasso, Ridge
lasso = Lasso(alpha=0.1)  # Set the regularization strength (alpha)
lasso.fit(X_train, y_train)
lasso_pred = lasso.predict(X_test)
lasso_mse = mean_squared_error(y_test, lasso_pred)
print("Lasso Regression MSE:", lasso_mse)

#Ridge Regression
Ridge = Ridge(alpha=0.5)  # Set the regularization strength (alpha)
Ridge.fit(X_train, y_train)
Ridge_pred = Ridge.predict(X_test)
Ridge_mse = mean_squared_error(y_test, Ridge_pred)
print("Ridge Regression MSE:", Ridge_mse)
# Out:
# Lasso Regression MSE: 205862578.91942772
# Ridge Regression MSE: 137989546.31450325
